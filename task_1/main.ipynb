# %% [markdown]
# # **_Task 1 - Analysis on ML Test Scores_**

# %%
import pandas as pd

# %%
data = pd.read_csv('scores_data.csv')
data.head()
# Out:
#        Batch  User_ID     Score
# 0  AI_ELITE_7  uid_149       6 / 7
# 1  AI_ELITE_7  uid_148       6 / 7
# 2  AI_ELITE_7  uid_147       7 / 7
# 3  AI_ELITE_7  uid_146       7 / 7
# 4  AI_ELITE_7  uid_145       4 / 7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Batch        149 non-null    object
#  1   User_ID      149 non-null    object
#  2      Score     149 non-null    object
# dtypes: object(3)
# memory usage: 3.6+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data=data , x=data['   Score   '],hue=data['Batch '])
# Out:
# <Axes: xlabel='   Score   ', ylabel='count'>

# %%
data['Score_int'] = data['   Score   '].str.split('/').str[0].astype(int)
data['Score_int']
# Out:
# 0      6
# 1      6
# 2      7
# 3      7
# 4      4
#       ..
# 144    4
# 145    4
# 146    4
# 147    3
# 148    2
# Name: Score_int, Length: 149, dtype: int64

# %%
data.describe()
# Out:
#         Score_int
# count  149.000000
# mean     4.382550
# std      1.592199
# min      0.000000
# 25%      3.000000
# 50%      4.000000
# 75%      5.000000
# max      7.000000

# %%
data.head()
# Out:
#        Batch  User_ID     Score     Score_int
# 0  AI_ELITE_7  uid_149       6 / 7          6
# 1  AI_ELITE_7  uid_148       6 / 7          6
# 2  AI_ELITE_7  uid_147       7 / 7          7
# 3  AI_ELITE_7  uid_146       7 / 7          7
# 4  AI_ELITE_7  uid_145       4 / 7          4

# %%
sns.countplot(data=data,x=data['Score_int'],hue=data['Batch '])
# Out:
# <Axes: xlabel='Score_int', ylabel='count'>

# %% [markdown]
# ## What this plot clearly tells us
#
# ###  AI_ELITE_6
#
# Scores are spread out
#
# Presence across low → high scores
#
# Indicates mixed performance
#
# Some strong performers, some weak → inconsistent batch
#
# Interpretation:
#
# AI_ELITE_6 has variability in learning outcomes.
#
#
# ###  AI_ELITE_4
#
# Heavy concentration around score = 4
#
# Fewer high scorers (6–7)
#
# Some low scores present
#
# Interpretation:
#
# AI_ELITE_4 shows average performance with limited high-end excellence.
#
# This batch likely needs intervention to push top performers.
#
#
#
# ###  AI_ELITE_7
#
# Strong concentration at 5, 6, 7
#
# Very few low scores
#
# Distribution shifted to the right
#
# Interpretation:
#
# AI_ELITE_7 is the strongest performing and most reliable batch.
#
# This is your best batch.

# %%
gp = data.groupby('Batch ')['Score_int'].mean()
print(gp)
# Out:
# Batch
# AI_ELITE_4    3.791667
# AI_ELITE_6    4.229167
# AI_ELITE_7    5.056604
# Name: Score_int, dtype: float64

# %%
data['Batch '].value_counts()
# Out:
# Batch
# AI_ELITE_7    53
# AI_ELITE_6    48
# AI_ELITE_4    48
# Name: count, dtype: int64

# %% [markdown]
# ###  The score distribution across batches shows clear performance differences. AI_ELITE_7 consistently achieves higher scores with minimal low-score occurrences, indicating strong overall performance. AI_ELITE_6 displays a wide spread of scores, suggesting inconsistent outcomes among users. AI_ELITE_4 is centered around mid-range scores with fewer high performers, reflecting average batch performance.

# %% [markdown]
# ## Insights
#
#     Batch performance differs not only in terms of average scores but also in consistency and score distribution.
#
#     AI_ELITE_7 emerges as the strongest performing batch, combining higher scores with lower variability.
#
#     AI_ELITE_6 shows potential but lacks consistency, indicating a possible need for targeted interventions.
#
#     AI_ELITE_4 maintains stable mid-level performance but may require strategies to encourage high achievers.

# %% [markdown]
# ## Conclusion
#
#     This EDA highlights the importance of analyzing score distributions rather than relying solely on summary statistics like mean. Visual comparison across batches provides deeper insights into performance patterns, consistency, and batch effectiveness, which can guide further analysis or modeling steps.
